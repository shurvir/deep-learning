# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/input/cifar-10/python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# CIFAR-10 Dataset: 171MB [02:22, 1.20MB/s]
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 0 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    norm = x / x.max(axis=0)
    return norm


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    from sklearn.preprocessing import OneHotEncoder
    
    enc = OneHotEncoder(categorical_features='all', dtype=np.float64,
       handle_unknown='error', n_values=10, sparse=True)
    
    X = np.array(x)[:,None]
    enc.fit(X)
    
    return enc.transform(X).toarray()


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    return tf.placeholder(tf.float32, shape=(None,) + image_shape, name='x')


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    return tf.placeholder(tf.float32, shape=(None, n_classes), name='y')


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    return tf.placeholder(tf.float32, name='keep_prob')


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    weightShape = x_tensor.get_shape().as_list()
    weightShape.extend([conv_num_outputs])
    W = tf.Variable(tf.truncated_normal(weightShape[1:], stddev=0.07))
    b = tf.Variable(tf.zeros([conv_num_outputs]))
    x_tensor = tf.nn.conv2d(x_tensor, W, strides=[1, conv_strides[0], conv_strides[1], 1], padding='SAME')
    x_tensor = tf.nn.bias_add(x_tensor, b)
    x_tensor = tf.nn.relu(x_tensor)
    x_tensor = tf.nn.max_pool(x_tensor,
                              ksize=[1, pool_ksize[0], pool_ksize[1], 1],
                              strides=[1, pool_strides[0], pool_strides[1], 1], 
                              padding='SAME')
    return x_tensor 


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    import operator, functools
    shape = x_tensor.get_shape().as_list()
    shape = [-1, functools.reduce(operator.mul, shape[1:], 1)]
    x_tensor = tf.reshape(x_tensor, shape)
    return x_tensor


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    shape = x_tensor.get_shape().as_list()
    W = tf.Variable(tf.truncated_normal([shape[1],num_outputs], stddev=0.07))
    b = tf.Variable(tf.zeros([num_outputs]))
    fc = tf.add(tf.matmul(x_tensor, W), b)
    fc = tf.nn.relu(fc)
    return fc


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    shape = x_tensor.get_shape().as_list()
    W = tf.Variable(tf.truncated_normal([shape[1],num_outputs],stddev=0.07))
    b = tf.Variable(tf.zeros([num_outputs]))
    x_tensor = tf.add(tf.matmul(x_tensor, W), b)
    return x_tensor


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    net = conv2d_maxpool(x, 32, 3, [1,1], [2,2], [2,2])
    print("conv1.shape(): " + str(net.get_shape()))

    net = conv2d_maxpool(net, 64, 3, [1,1], [2,2], [2,2])
    print("conv2.shape(): " + str(net.get_shape()))
    
    net = conv2d_maxpool(net, 128, 3, [1,1], [2,2], [2,2])
    print("conv3.shape(): " + str(net.get_shape()))
    
    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    net = flatten(net)
    print("flatten.shape(): " + str(net.get_shape()))
    
    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    net = fully_conn(net, 2048)
    net = fully_conn(net, 1024)
    #net = fully_conn(net, 32)
    
    # Add dropout
    net = tf.nn.dropout(net, keep_prob)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    net = output(net, 10)
    
    # TODO: return output
    return net


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# conv1.shape(): (?, 16, 16, 32)
# conv2.shape(): (?, 8, 8, 64)
# conv3.shape(): (?, 4, 4, 128)
# flatten.shape(): (?, 2048)
# conv1.shape(): (?, 16, 16, 32)
# conv2.shape(): (?, 8, 8, 64)
# conv3.shape(): (?, 4, 4, 128)
# flatten.shape(): (?, 2048)
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    session.run(optimizer, feed_dict={
                x: feature_batch,
                y: label_batch,
                keep_prob: keep_probability})


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    loss = session.run(cost, feed_dict={
                x: feature_batch,
                y: label_batch,
                keep_prob: 1.})
    valid_acc = session.run(accuracy, feed_dict={
        x: valid_features,
        y: valid_labels,
        keep_prob: 1.})

    print('Loss: {:>10.4f} Validation Accuracy: {:.6f}'.format(loss,valid_acc))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 500
batch_size = 128
keep_probability = 0.5

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Loss:     2.3021 Validation Accuracy: 0.101600
# Epoch  2, CIFAR-10 Batch 1:  Loss:     2.3010 Validation Accuracy: 0.101800
# Epoch  3, CIFAR-10 Batch 1:  Loss:     2.3000 Validation Accuracy: 0.103600
# Epoch  4, CIFAR-10 Batch 1:  Loss:     2.2364 Validation Accuracy: 0.130000
# Epoch  5, CIFAR-10 Batch 1:  Loss:     2.2427 Validation Accuracy: 0.153400
# Epoch  6, CIFAR-10 Batch 1:  Loss:     2.1051 Validation Accuracy: 0.209400
# Epoch  7, CIFAR-10 Batch 1:  Loss:     2.0201 Validation Accuracy: 0.251000
# Epoch  8, CIFAR-10 Batch 1:  Loss:     1.9194 Validation Accuracy: 0.295800
# Epoch  9, CIFAR-10 Batch 1:  Loss:     1.8850 Validation Accuracy: 0.269000
# Epoch 10, CIFAR-10 Batch 1:  Loss:     1.7245 Validation Accuracy: 0.281000
# Epoch 11, CIFAR-10 Batch 1:  Loss:     1.6526 Validation Accuracy: 0.285400
# Epoch 12, CIFAR-10 Batch 1:  Loss:     1.5955 Validation Accuracy: 0.282400
# Epoch 13, CIFAR-10 Batch 1:  Loss:     1.3461 Validation Accuracy: 0.326800
# Epoch 14, CIFAR-10 Batch 1:  Loss:     1.3445 Validation Accuracy: 0.308800
# Epoch 15, CIFAR-10 Batch 1:  Loss:     1.4463 Validation Accuracy: 0.290600
# Epoch 16, CIFAR-10 Batch 1:  Loss:     1.1056 Validation Accuracy: 0.316000
# Epoch 17, CIFAR-10 Batch 1:  Loss:     0.9169 Validation Accuracy: 0.331400
# Epoch 18, CIFAR-10 Batch 1:  Loss:     0.8634 Validation Accuracy: 0.337800
# Epoch 19, CIFAR-10 Batch 1:  Loss:     0.8223 Validation Accuracy: 0.323000
# Epoch 20, CIFAR-10 Batch 1:  Loss:     0.9345 Validation Accuracy: 0.306400
# Epoch 21, CIFAR-10 Batch 1:  Loss:     0.8449 Validation Accuracy: 0.328600
# Epoch 22, CIFAR-10 Batch 1:  Loss:     1.0223 Validation Accuracy: 0.311600
# Epoch 23, CIFAR-10 Batch 1:  Loss:     0.7689 Validation Accuracy: 0.336400
# Epoch 24, CIFAR-10 Batch 1:  Loss:     0.5914 Validation Accuracy: 0.335800
# Epoch 25, CIFAR-10 Batch 1:  Loss:     0.6321 Validation Accuracy: 0.344600
# Epoch 26, CIFAR-10 Batch 1:  Loss:     0.6311 Validation Accuracy: 0.314000
# Epoch 27, CIFAR-10 Batch 1:  Loss:     0.6741 Validation Accuracy: 0.291400
# Epoch 28, CIFAR-10 Batch 1:  Loss:     0.6109 Validation Accuracy: 0.275800
# Epoch 29, CIFAR-10 Batch 1:  Loss:     0.5576 Validation Accuracy: 0.301200
# Epoch 30, CIFAR-10 Batch 1:  Loss:     0.4994 Validation Accuracy: 0.307600
# Epoch 31, CIFAR-10 Batch 1:  Loss:     0.4775 Validation Accuracy: 0.296600
# Epoch 32, CIFAR-10 Batch 1:  Loss:     0.3618 Validation Accuracy: 0.304800
# Epoch 33, CIFAR-10 Batch 1:  Loss:     0.2625 Validation Accuracy: 0.314200
# Epoch 34, CIFAR-10 Batch 1:  Loss:     0.1581 Validation Accuracy: 0.319200
# Epoch 35, CIFAR-10 Batch 1:  Loss:     0.3254 Validation Accuracy: 0.305200
# Epoch 36, CIFAR-10 Batch 1:  Loss:     0.1143 Validation Accuracy: 0.323000
# Epoch 37, CIFAR-10 Batch 1:  Loss:     0.0544 Validation Accuracy: 0.324800
# Epoch 38, CIFAR-10 Batch 1:  Loss:     0.0474 Validation Accuracy: 0.321000
# Epoch 39, CIFAR-10 Batch 1:  Loss:     0.0763 Validation Accuracy: 0.304600
# Epoch 40, CIFAR-10 Batch 1:  Loss:     0.0738 Validation Accuracy: 0.298200
# Epoch 41, CIFAR-10 Batch 1:  Loss:     0.0729 Validation Accuracy: 0.302400
# Epoch 42, CIFAR-10 Batch 1:  Loss:     0.1242 Validation Accuracy: 0.274200
# Epoch 43, CIFAR-10 Batch 1:  Loss:     0.2657 Validation Accuracy: 0.264200
# Epoch 44, CIFAR-10 Batch 1:  Loss:     0.0325 Validation Accuracy: 0.303400
# Epoch 45, CIFAR-10 Batch 1:  Loss:     0.0409 Validation Accuracy: 0.302000
# Epoch 46, CIFAR-10 Batch 1:  Loss:     0.0737 Validation Accuracy: 0.295200
# Epoch 47, CIFAR-10 Batch 1:  Loss:     0.1061 Validation Accuracy: 0.280600
# Epoch 48, CIFAR-10 Batch 1:  Loss:     0.3174 Validation Accuracy: 0.293000
# Epoch 49, CIFAR-10 Batch 1:  Loss:     0.3591 Validation Accuracy: 0.261000
# Epoch 50, CIFAR-10 Batch 1:  Loss:     0.2668 Validation Accuracy: 0.290800
# Epoch 51, CIFAR-10 Batch 1:  Loss:     0.1428 Validation Accuracy: 0.302600
# Epoch 52, CIFAR-10 Batch 1:  Loss:     0.0525 Validation Accuracy: 0.336400
# Epoch 53, CIFAR-10 Batch 1:  Loss:     0.0199 Validation Accuracy: 0.330600
# Epoch 54, CIFAR-10 Batch 1:  Loss:     0.0121 Validation Accuracy: 0.344800
# Epoch 55, CIFAR-10 Batch 1:  Loss:     0.0212 Validation Accuracy: 0.329400
# Epoch 56, CIFAR-10 Batch 1:  Loss:     0.0112 Validation Accuracy: 0.330800
# Epoch 57, CIFAR-10 Batch 1:  Loss:     0.0404 Validation Accuracy: 0.322400

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Loss:     2.0620 Validation Accuracy: 0.226200
# Epoch  1, CIFAR-10 Batch 2:  Loss:     1.9868 Validation Accuracy: 0.307600
# Epoch  1, CIFAR-10 Batch 3:  Loss:     1.6907 Validation Accuracy: 0.350000
# Epoch  1, CIFAR-10 Batch 4:  Loss:     1.5090 Validation Accuracy: 0.364000
# Epoch  1, CIFAR-10 Batch 5:  Loss:     1.6783 Validation Accuracy: 0.370200
# Epoch  2, CIFAR-10 Batch 1:  Loss:     1.7209 Validation Accuracy: 0.407200
# Epoch  2, CIFAR-10 Batch 2:  Loss:     1.4071 Validation Accuracy: 0.413400
# Epoch  2, CIFAR-10 Batch 3:  Loss:     1.1777 Validation Accuracy: 0.413000
# Epoch  2, CIFAR-10 Batch 4:  Loss:     1.0829 Validation Accuracy: 0.420800
# Epoch  2, CIFAR-10 Batch 5:  Loss:     1.3333 Validation Accuracy: 0.420600
# Epoch  3, CIFAR-10 Batch 1:  Loss:     1.2969 Validation Accuracy: 0.437800
# Epoch  3, CIFAR-10 Batch 2:  Loss:     1.0716 Validation Accuracy: 0.438200
# Epoch  3, CIFAR-10 Batch 3:  Loss:     0.9124 Validation Accuracy: 0.455800
# Epoch  3, CIFAR-10 Batch 4:  Loss:     0.7640 Validation Accuracy: 0.450800
# Epoch  3, CIFAR-10 Batch 5:  Loss:     1.0244 Validation Accuracy: 0.430000
# Epoch  4, CIFAR-10 Batch 1:  Loss:     1.0166 Validation Accuracy: 0.449200
# Epoch  4, CIFAR-10 Batch 2:  Loss:     0.7962 Validation Accuracy: 0.450400
# Epoch  4, CIFAR-10 Batch 3:  Loss:     0.6999 Validation Accuracy: 0.465600
# Epoch  4, CIFAR-10 Batch 4:  Loss:     0.5770 Validation Accuracy: 0.459000
# Epoch  4, CIFAR-10 Batch 5:  Loss:     0.7826 Validation Accuracy: 0.447200
# Epoch  5, CIFAR-10 Batch 1:  Loss:     0.7585 Validation Accuracy: 0.457600
# Epoch  5, CIFAR-10 Batch 2:  Loss:     0.5870 Validation Accuracy: 0.462000
# Epoch  5, CIFAR-10 Batch 3:  Loss:     0.5194 Validation Accuracy: 0.481600
# Epoch  5, CIFAR-10 Batch 4:  Loss:     0.4150 Validation Accuracy: 0.456200
# Epoch  5, CIFAR-10 Batch 5:  Loss:     0.5870 Validation Accuracy: 0.464600
# Epoch  6, CIFAR-10 Batch 1:  Loss:     0.6349 Validation Accuracy: 0.464600
# Epoch  6, CIFAR-10 Batch 2:  Loss:     0.4561 Validation Accuracy: 0.456600
# Epoch  6, CIFAR-10 Batch 3:  Loss:     0.4255 Validation Accuracy: 0.464800
# Epoch  6, CIFAR-10 Batch 4:  Loss:     0.3869 Validation Accuracy: 0.461000
# Epoch  6, CIFAR-10 Batch 5:  Loss:     0.4452 Validation Accuracy: 0.480200
# Epoch  7, CIFAR-10 Batch 1:  Loss:     0.4976 Validation Accuracy: 0.464400
# Epoch  7, CIFAR-10 Batch 2:  Loss:     0.4410 Validation Accuracy: 0.450000
# Epoch  7, CIFAR-10 Batch 3:  Loss:     0.3941 Validation Accuracy: 0.469400
# Epoch  7, CIFAR-10 Batch 4:  Loss:     0.3046 Validation Accuracy: 0.470800
# Epoch  7, CIFAR-10 Batch 5:  Loss:     0.3554 Validation Accuracy: 0.491400
# Epoch  8, CIFAR-10 Batch 1:  Loss:     0.4821 Validation Accuracy: 0.445400
# Epoch  8, CIFAR-10 Batch 2:  Loss:     0.2981 Validation Accuracy: 0.473000
# Epoch  8, CIFAR-10 Batch 3:  Loss:     0.3497 Validation Accuracy: 0.473800
# Epoch  8, CIFAR-10 Batch 4:  Loss:     0.2384 Validation Accuracy: 0.465200
# Epoch  8, CIFAR-10 Batch 5:  Loss:     0.4330 Validation Accuracy: 0.470800
# Epoch  9, CIFAR-10 Batch 1:  Loss:     0.5592 Validation Accuracy: 0.452400
# Epoch  9, CIFAR-10 Batch 2:  Loss:     0.3170 Validation Accuracy: 0.481200
# Epoch  9, CIFAR-10 Batch 3:  Loss:     0.2107 Validation Accuracy: 0.462800
# Epoch  9, CIFAR-10 Batch 4:  Loss:     0.2076 Validation Accuracy: 0.468000
# Epoch  9, CIFAR-10 Batch 5:  Loss:     0.3273 Validation Accuracy: 0.482800
# Epoch 10, CIFAR-10 Batch 1:  Loss:     0.3698 Validation Accuracy: 0.466000
# Epoch 10, CIFAR-10 Batch 2:  Loss:     0.3238 Validation Accuracy: 0.460400
# Epoch 10, CIFAR-10 Batch 3:  Loss:     0.1815 Validation Accuracy: 0.412800
# Epoch 10, CIFAR-10 Batch 4:  Loss:     0.2357 Validation Accuracy: 0.450400
# Epoch 10, CIFAR-10 Batch 5:  Loss:     0.3418 Validation Accuracy: 0.474400
# Epoch 11, CIFAR-10 Batch 1:  Loss:     0.2430 Validation Accuracy: 0.482600
# Epoch 11, CIFAR-10 Batch 2:  Loss:     0.3129 Validation Accuracy: 0.464000
# Epoch 11, CIFAR-10 Batch 3:  Loss:     0.2651 Validation Accuracy: 0.464400
# Epoch 11, CIFAR-10 Batch 4:  Loss:     0.2455 Validation Accuracy: 0.463800
# Epoch 11, CIFAR-10 Batch 5:  Loss:     0.2598 Validation Accuracy: 0.472000
# Epoch 12, CIFAR-10 Batch 1:  Loss:     0.2634 Validation Accuracy: 0.439400
# Epoch 12, CIFAR-10 Batch 2:  Loss:     0.1932 Validation Accuracy: 0.466200
# Epoch 12, CIFAR-10 Batch 3:  Loss:     0.1751 Validation Accuracy: 0.461000
# Epoch 12, CIFAR-10 Batch 4:  Loss:     0.1799 Validation Accuracy: 0.460000
# Epoch 12, CIFAR-10 Batch 5:  Loss:     0.2237 Validation Accuracy: 0.468000
# Epoch 13, CIFAR-10 Batch 1:  Loss:     0.1720 Validation Accuracy: 0.467800
# Epoch 13, CIFAR-10 Batch 2:  Loss:     0.1600 Validation Accuracy: 0.449600
# Epoch 13, CIFAR-10 Batch 3:  Loss:     0.1256 Validation Accuracy: 0.456400
# Epoch 13, CIFAR-10 Batch 4:  Loss:     0.1262 Validation Accuracy: 0.463600
# Epoch 13, CIFAR-10 Batch 5:  Loss:     0.2047 Validation Accuracy: 0.450400
# Epoch 14, CIFAR-10 Batch 1:  Loss:     0.1923 Validation Accuracy: 0.467400
# Epoch 14, CIFAR-10 Batch 2:  Loss:     0.1440 Validation Accuracy: 0.455400
# Epoch 14, CIFAR-10 Batch 3:  Loss:     0.0945 Validation Accuracy: 0.453200
# Epoch 14, CIFAR-10 Batch 4:  Loss:     0.1073 Validation Accuracy: 0.468200
# Epoch 14, CIFAR-10 Batch 5:  Loss:     0.1612 Validation Accuracy: 0.461200
# Epoch 15, CIFAR-10 Batch 1:  Loss:     0.1747 Validation Accuracy: 0.456000
# Epoch 15, CIFAR-10 Batch 2:  Loss:     0.1232 Validation Accuracy: 0.474000
# Epoch 15, CIFAR-10 Batch 3:  Loss:     0.0569 Validation Accuracy: 0.466600
# Epoch 15, CIFAR-10 Batch 4:  Loss:     0.1029 Validation Accuracy: 0.464800
# Epoch 15, CIFAR-10 Batch 5:  Loss:     0.1477 Validation Accuracy: 0.474600
# Epoch 16, CIFAR-10 Batch 1:  Loss:     0.2467 Validation Accuracy: 0.450600
# Epoch 16, CIFAR-10 Batch 2:  Loss:     0.1066 Validation Accuracy: 0.470800
# Epoch 16, CIFAR-10 Batch 3:  Loss:     0.1090 Validation Accuracy: 0.458000
# Epoch 16, CIFAR-10 Batch 4:  Loss:     0.0740 Validation Accuracy: 0.456800
# Epoch 16, CIFAR-10 Batch 5:  Loss:     0.1414 Validation Accuracy: 0.446600
# Epoch 17, CIFAR-10 Batch 1:  Loss:     0.0937 Validation Accuracy: 0.475400
# Epoch 17, CIFAR-10 Batch 2:  Loss:     0.0800 Validation Accuracy: 0.464600
# Epoch 17, CIFAR-10 Batch 3:  Loss:     0.0534 Validation Accuracy: 0.435000
# Epoch 17, CIFAR-10 Batch 4:  Loss:     0.1147 Validation Accuracy: 0.436600
# Epoch 17, CIFAR-10 Batch 5:  Loss:     0.1279 Validation Accuracy: 0.461400
# Epoch 18, CIFAR-10 Batch 1:  Loss:     0.0679 Validation Accuracy: 0.476800
# Epoch 18, CIFAR-10 Batch 2:  Loss:     0.0539 Validation Accuracy: 0.456200
# Epoch 18, CIFAR-10 Batch 3:  Loss:     0.0512 Validation Accuracy: 0.437800
# Epoch 18, CIFAR-10 Batch 4:  Loss:     0.0899 Validation Accuracy: 0.436800
# Epoch 18, CIFAR-10 Batch 5:  Loss:     0.1267 Validation Accuracy: 0.427000
# Epoch 19, CIFAR-10 Batch 1:  Loss:     0.0565 Validation Accuracy: 0.466800
# Epoch 19, CIFAR-10 Batch 2:  Loss:     0.0369 Validation Accuracy: 0.461400
# Epoch 19, CIFAR-10 Batch 3:  Loss:     0.0444 Validation Accuracy: 0.410000
# Epoch 19, CIFAR-10 Batch 4:  Loss:     0.0517 Validation Accuracy: 0.434600
# Epoch 19, CIFAR-10 Batch 5:  Loss:     0.0832 Validation Accuracy: 0.455800
# Epoch 20, CIFAR-10 Batch 1:  Loss:     0.0483 Validation Accuracy: 0.467600
# Epoch 20, CIFAR-10 Batch 2:  Loss:     0.0364 Validation Accuracy: 0.462400
# Epoch 20, CIFAR-10 Batch 3:  Loss:     0.0379 Validation Accuracy: 0.434800
# Epoch 20, CIFAR-10 Batch 4:  Loss:     0.0601 Validation Accuracy: 0.444600
# Epoch 20, CIFAR-10 Batch 5:  Loss:     0.0696 Validation Accuracy: 0.461200
# Epoch 21, CIFAR-10 Batch 1:  Loss:     0.0564 Validation Accuracy: 0.460600
# Epoch 21, CIFAR-10 Batch 2:  Loss:     0.0238 Validation Accuracy: 0.475600
# Epoch 21, CIFAR-10 Batch 3:  Loss:     0.0197 Validation Accuracy: 0.431600
# Epoch 21, CIFAR-10 Batch 4:  Loss:     0.0580 Validation Accuracy: 0.447400
# Epoch 21, CIFAR-10 Batch 5:  Loss:     0.0538 Validation Accuracy: 0.434200
# Epoch 22, CIFAR-10 Batch 1:  Loss:     0.0579 Validation Accuracy: 0.461400
# Epoch 22, CIFAR-10 Batch 2:  Loss:     0.0335 Validation Accuracy: 0.456600
# Epoch 22, CIFAR-10 Batch 3:  Loss:     0.0225 Validation Accuracy: 0.430200
# Epoch 22, CIFAR-10 Batch 4:  Loss:     0.0244 Validation Accuracy: 0.442400
# Epoch 22, CIFAR-10 Batch 5:  Loss:     0.0611 Validation Accuracy: 0.467600
# Epoch 23, CIFAR-10 Batch 1:  Loss:     0.0562 Validation Accuracy: 0.443200
# Epoch 23, CIFAR-10 Batch 2:  Loss:     0.0387 Validation Accuracy: 0.434800
# Epoch 23, CIFAR-10 Batch 3:  Loss:     0.0770 Validation Accuracy: 0.468400
# Epoch 23, CIFAR-10 Batch 4:  Loss:     0.0452 Validation Accuracy: 0.450400
# Epoch 23, CIFAR-10 Batch 5:  Loss:     0.0740 Validation Accuracy: 0.456800
# Epoch 24, CIFAR-10 Batch 1:  Loss:     0.0320 Validation Accuracy: 0.462000
# Epoch 24, CIFAR-10 Batch 2:  Loss:     0.0335 Validation Accuracy: 0.459400
# Epoch 24, CIFAR-10 Batch 3:  Loss:     0.0607 Validation Accuracy: 0.443400
# Epoch 24, CIFAR-10 Batch 4:  Loss:     0.0226 Validation Accuracy: 0.454400
# Epoch 24, CIFAR-10 Batch 5:  Loss:     0.0588 Validation Accuracy: 0.422600
# Epoch 25, CIFAR-10 Batch 1:  Loss:     0.0283 Validation Accuracy: 0.468200
# Epoch 25, CIFAR-10 Batch 2:  Loss:     0.0248 Validation Accuracy: 0.460800
# Epoch 25, CIFAR-10 Batch 3:  Loss:     0.0484 Validation Accuracy: 0.436000
# Epoch 25, CIFAR-10 Batch 4:  Loss:     0.0206 Validation Accuracy: 0.458000
# Epoch 25, CIFAR-10 Batch 5:  Loss:     0.0536 Validation Accuracy: 0.420600
# Epoch 26, CIFAR-10 Batch 1:  Loss:     0.0226 Validation Accuracy: 0.457400
# Epoch 26, CIFAR-10 Batch 2:  Loss:     0.0146 Validation Accuracy: 0.456400
# Epoch 26, CIFAR-10 Batch 3:  Loss:     0.0309 Validation Accuracy: 0.425200
# Epoch 26, CIFAR-10 Batch 4:  Loss:     0.0191 Validation Accuracy: 0.461800
# Epoch 26, CIFAR-10 Batch 5:  Loss:     0.0454 Validation Accuracy: 0.443200
# Epoch 27, CIFAR-10 Batch 1:  Loss:     0.0226 Validation Accuracy: 0.456400
# Epoch 27, CIFAR-10 Batch 2:  Loss:     0.0153 Validation Accuracy: 0.442800
# Epoch 27, CIFAR-10 Batch 3:  Loss:     0.0317 Validation Accuracy: 0.432000
# Epoch 27, CIFAR-10 Batch 4:  Loss:     0.0191 Validation Accuracy: 0.457400
# Epoch 27, CIFAR-10 Batch 5:  Loss:     0.0270 Validation Accuracy: 0.458600
# Epoch 28, CIFAR-10 Batch 1:  Loss:     0.0272 Validation Accuracy: 0.453400
# Epoch 28, CIFAR-10 Batch 2:  Loss:     0.0222 Validation Accuracy: 0.453800
# Epoch 28, CIFAR-10 Batch 3:  Loss:     0.0099 Validation Accuracy: 0.446600
# Epoch 28, CIFAR-10 Batch 4:  Loss:     0.0150 Validation Accuracy: 0.469800
# Epoch 28, CIFAR-10 Batch 5:  Loss:     0.0245 Validation Accuracy: 0.414600
# Epoch 29, CIFAR-10 Batch 1:  Loss:     0.0266 Validation Accuracy: 0.444400
# Epoch 29, CIFAR-10 Batch 2:  Loss:     0.0092 Validation Accuracy: 0.455400
# Epoch 29, CIFAR-10 Batch 3:  Loss:     0.0071 Validation Accuracy: 0.445800
# Epoch 29, CIFAR-10 Batch 4:  Loss:     0.0060 Validation Accuracy: 0.468200
# Epoch 29, CIFAR-10 Batch 5:  Loss:     0.0122 Validation Accuracy: 0.433800
# Epoch 30, CIFAR-10 Batch 1:  Loss:     0.0223 Validation Accuracy: 0.459600
# Epoch 30, CIFAR-10 Batch 2:  Loss:     0.0063 Validation Accuracy: 0.455200
# Epoch 30, CIFAR-10 Batch 3:  Loss:     0.0046 Validation Accuracy: 0.462200
# Epoch 30, CIFAR-10 Batch 4:  Loss:     0.0053 Validation Accuracy: 0.466800
# Epoch 30, CIFAR-10 Batch 5:  Loss:     0.0099 Validation Accuracy: 0.424600
# Epoch 31, CIFAR-10 Batch 1:  Loss:     0.0104 Validation Accuracy: 0.466800
# Epoch 31, CIFAR-10 Batch 2:  Loss:     0.0081 Validation Accuracy: 0.457400
# Epoch 31, CIFAR-10 Batch 3:  Loss:     0.0045 Validation Accuracy: 0.438400
# Epoch 31, CIFAR-10 Batch 4:  Loss:     0.0112 Validation Accuracy: 0.448000
# Epoch 31, CIFAR-10 Batch 5:  Loss:     0.0124 Validation Accuracy: 0.449000
# Epoch 32, CIFAR-10 Batch 1:  Loss:     0.0103 Validation Accuracy: 0.452000
# Epoch 32, CIFAR-10 Batch 2:  Loss:     0.0089 Validation Accuracy: 0.431000
# Epoch 32, CIFAR-10 Batch 3:  Loss:     0.0049 Validation Accuracy: 0.446600
# Epoch 32, CIFAR-10 Batch 4:  Loss:     0.0037 Validation Accuracy: 0.466200
# Epoch 32, CIFAR-10 Batch 5:  Loss:     0.0151 Validation Accuracy: 0.450400
# Epoch 33, CIFAR-10 Batch 1:  Loss:     0.0092 Validation Accuracy: 0.434400
# Epoch 33, CIFAR-10 Batch 2:  Loss:     0.0075 Validation Accuracy: 0.448000
# Epoch 33, CIFAR-10 Batch 3:  Loss:     0.0037 Validation Accuracy: 0.458800
# Epoch 33, CIFAR-10 Batch 4:  Loss:     0.0048 Validation Accuracy: 0.469400
# Epoch 33, CIFAR-10 Batch 5:  Loss:     0.0111 Validation Accuracy: 0.460000
# Epoch 34, CIFAR-10 Batch 1:  Loss:     0.0101 Validation Accuracy: 0.448400
# Epoch 34, CIFAR-10 Batch 2:  Loss:     0.0057 Validation Accuracy: 0.452200
# Epoch 34, CIFAR-10 Batch 3:  Loss:     0.0024 Validation Accuracy: 0.457000
# Epoch 34, CIFAR-10 Batch 4:  Loss:     0.0025 Validation Accuracy: 0.462200
# Epoch 34, CIFAR-10 Batch 5:  Loss:     0.0161 Validation Accuracy: 0.446400
# Epoch 35, CIFAR-10 Batch 1:  Loss:     0.0152 Validation Accuracy: 0.449600
# Epoch 35, CIFAR-10 Batch 2:  Loss:     0.0040 Validation Accuracy: 0.458400
# Epoch 35, CIFAR-10 Batch 3:  Loss:     0.0047 Validation Accuracy: 0.454200
# Epoch 35, CIFAR-10 Batch 4:  Loss:     0.0032 Validation Accuracy: 0.445600
# Epoch 35, CIFAR-10 Batch 5:  Loss:     0.0104 Validation Accuracy: 0.435800
# Epoch 36, CIFAR-10 Batch 1:  Loss:     0.0079 Validation Accuracy: 0.454800
# Epoch 36, CIFAR-10 Batch 2:  Loss:     0.0034 Validation Accuracy: 0.464000
# Epoch 36, CIFAR-10 Batch 3:  Loss:     0.0047 Validation Accuracy: 0.456200
# Epoch 36, CIFAR-10 Batch 4:  Loss:     0.0082 Validation Accuracy: 0.458600
# Epoch 36, CIFAR-10 Batch 5:  Loss:     0.0077 Validation Accuracy: 0.441400
# Epoch 37, CIFAR-10 Batch 1:  Loss:     0.0049 Validation Accuracy: 0.467200
# Epoch 37, CIFAR-10 Batch 2:  Loss:     0.0057 Validation Accuracy: 0.456800
# Epoch 37, CIFAR-10 Batch 3:  Loss:     0.0173 Validation Accuracy: 0.446000
# Epoch 37, CIFAR-10 Batch 4:  Loss:     0.0068 Validation Accuracy: 0.476200
# Epoch 37, CIFAR-10 Batch 5:  Loss:     0.0101 Validation Accuracy: 0.422800
# Epoch 38, CIFAR-10 Batch 1:  Loss:     0.0019 Validation Accuracy: 0.473000
# Epoch 38, CIFAR-10 Batch 2:  Loss:     0.0028 Validation Accuracy: 0.464800
# Epoch 38, CIFAR-10 Batch 3:  Loss:     0.0053 Validation Accuracy: 0.451400
# Epoch 38, CIFAR-10 Batch 4:  Loss:     0.0120 Validation Accuracy: 0.465800
# Epoch 38, CIFAR-10 Batch 5:  Loss:     0.0046 Validation Accuracy: 0.431600
# Epoch 39, CIFAR-10 Batch 1:  Loss:     0.0038 Validation Accuracy: 0.469800
# Epoch 39, CIFAR-10 Batch 2:  Loss:     0.0057 Validation Accuracy: 0.450000
# Epoch 39, CIFAR-10 Batch 3:  Loss:     0.0066 Validation Accuracy: 0.460400
# Epoch 39, CIFAR-10 Batch 4:  Loss:     0.0043 Validation Accuracy: 0.473400
# Epoch 39, CIFAR-10 Batch 5:  Loss:     0.0045 Validation Accuracy: 0.421800
# Epoch 40, CIFAR-10 Batch 1:  Loss:     0.0052 Validation Accuracy: 0.454000
# Epoch 40, CIFAR-10 Batch 2:  Loss:     0.0017 Validation Accuracy: 0.461400
# Epoch 40, CIFAR-10 Batch 3:  Loss:     0.0089 Validation Accuracy: 0.443400
# Epoch 40, CIFAR-10 Batch 4:  Loss:     0.0018 Validation Accuracy: 0.472000
# Epoch 40, CIFAR-10 Batch 5:  Loss:     0.0035 Validation Accuracy: 0.416000
# Epoch 41, CIFAR-10 Batch 1:  Loss:     0.0030 Validation Accuracy: 0.466800
# Epoch 41, CIFAR-10 Batch 2:  Loss:     0.0027 Validation Accuracy: 0.466800
# Epoch 41, CIFAR-10 Batch 3:  Loss:     0.0042 Validation Accuracy: 0.443400
# Epoch 41, CIFAR-10 Batch 4:  Loss:     0.0019 Validation Accuracy: 0.470800
# Epoch 41, CIFAR-10 Batch 5:  Loss:     0.0131 Validation Accuracy: 0.430800
# Epoch 42, CIFAR-10 Batch 1:  Loss:     0.0024 Validation Accuracy: 0.461800
# Epoch 42, CIFAR-10 Batch 2:  Loss:     0.0023 Validation Accuracy: 0.459000
# Epoch 42, CIFAR-10 Batch 3:  Loss:     0.0023 Validation Accuracy: 0.457600
# Epoch 42, CIFAR-10 Batch 4:  Loss:     0.0013 Validation Accuracy: 0.458800
# Epoch 42, CIFAR-10 Batch 5:  Loss:     0.0034 Validation Accuracy: 0.441400
# Epoch 43, CIFAR-10 Batch 1:  Loss:     0.0056 Validation Accuracy: 0.444600
# Epoch 43, CIFAR-10 Batch 2:  Loss:     0.0018 Validation Accuracy: 0.461200
# Epoch 43, CIFAR-10 Batch 3:  Loss:     0.0021 Validation Accuracy: 0.459400
# Epoch 43, CIFAR-10 Batch 4:  Loss:     0.0052 Validation Accuracy: 0.450600
# Epoch 43, CIFAR-10 Batch 5:  Loss:     0.0046 Validation Accuracy: 0.435400
# Epoch 44, CIFAR-10 Batch 1:  Loss:     0.0022 Validation Accuracy: 0.460000
# Epoch 44, CIFAR-10 Batch 2:  Loss:     0.0039 Validation Accuracy: 0.464200
# Epoch 44, CIFAR-10 Batch 3:  Loss:     0.0030 Validation Accuracy: 0.460400
# Epoch 44, CIFAR-10 Batch 4:  Loss:     0.0032 Validation Accuracy: 0.471200
# Epoch 44, CIFAR-10 Batch 5:  Loss:     0.0037 Validation Accuracy: 0.475400
# Epoch 45, CIFAR-10 Batch 1:  Loss:     0.0012 Validation Accuracy: 0.451800
# Epoch 45, CIFAR-10 Batch 2:  Loss:     0.0042 Validation Accuracy: 0.460000
# Epoch 45, CIFAR-10 Batch 3:  Loss:     0.0017 Validation Accuracy: 0.461600
# Epoch 45, CIFAR-10 Batch 4:  Loss:     0.0029 Validation Accuracy: 0.472200
# Epoch 45, CIFAR-10 Batch 5:  Loss:     0.0021 Validation Accuracy: 0.453200
# Epoch 46, CIFAR-10 Batch 1:  Loss:     0.0031 Validation Accuracy: 0.449200
# Epoch 46, CIFAR-10 Batch 2:  Loss:     0.0038 Validation Accuracy: 0.456800
# Epoch 46, CIFAR-10 Batch 3:  Loss:     0.0027 Validation Accuracy: 0.456400
# Epoch 46, CIFAR-10 Batch 4:  Loss:     0.0021 Validation Accuracy: 0.464000
# Epoch 46, CIFAR-10 Batch 5:  Loss:     0.0110 Validation Accuracy: 0.437400
# Epoch 47, CIFAR-10 Batch 1:  Loss:     0.0043 Validation Accuracy: 0.437200
# Epoch 47, CIFAR-10 Batch 2:  Loss:     0.0014 Validation Accuracy: 0.462200
# Epoch 47, CIFAR-10 Batch 3:  Loss:     0.0020 Validation Accuracy: 0.466000
# Epoch 47, CIFAR-10 Batch 4:  Loss:     0.0017 Validation Accuracy: 0.466200
# Epoch 47, CIFAR-10 Batch 5:  Loss:     0.0056 Validation Accuracy: 0.451000
# Epoch 48, CIFAR-10 Batch 1:  Loss:     0.0048 Validation Accuracy: 0.429800
# Epoch 48, CIFAR-10 Batch 2:  Loss:     0.0016 Validation Accuracy: 0.462400
# Epoch 48, CIFAR-10 Batch 3:  Loss:     0.0020 Validation Accuracy: 0.459000
# Epoch 48, CIFAR-10 Batch 4:  Loss:     0.0028 Validation Accuracy: 0.472200
# Epoch 48, CIFAR-10 Batch 5:  Loss:     0.0044 Validation Accuracy: 0.466200
# Epoch 49, CIFAR-10 Batch 1:  Loss:     0.0043 Validation Accuracy: 0.442400
# Epoch 49, CIFAR-10 Batch 2:  Loss:     0.0013 Validation Accuracy: 0.468800
# Epoch 49, CIFAR-10 Batch 3:  Loss:     0.0010 Validation Accuracy: 0.461400
# Epoch 49, CIFAR-10 Batch 4:  Loss:     0.0018 Validation Accuracy: 0.469000
# Epoch 49, CIFAR-10 Batch 5:  Loss:     0.0050 Validation Accuracy: 0.468400
# Epoch 50, CIFAR-10 Batch 1:  Loss:     0.0031 Validation Accuracy: 0.436400
# Epoch 50, CIFAR-10 Batch 2:  Loss:     0.0006 Validation Accuracy: 0.468200
# Epoch 50, CIFAR-10 Batch 3:  Loss:     0.0028 Validation Accuracy: 0.462200
# Epoch 50, CIFAR-10 Batch 4:  Loss:     0.0004 Validation Accuracy: 0.471200
# Epoch 50, CIFAR-10 Batch 5:  Loss:     0.0018 Validation Accuracy: 0.472400
# Epoch 51, CIFAR-10 Batch 1:  Loss:     0.0047 Validation Accuracy: 0.439200
# Epoch 51, CIFAR-10 Batch 2:  Loss:     0.0016 Validation Accuracy: 0.465800
# Epoch 51, CIFAR-10 Batch 3:  Loss:     0.0009 Validation Accuracy: 0.470200
# Epoch 51, CIFAR-10 Batch 4:  Loss:     0.0010 Validation Accuracy: 0.476800
# Epoch 51, CIFAR-10 Batch 5:  Loss:     0.0016 Validation Accuracy: 0.475400
# Epoch 52, CIFAR-10 Batch 1:  Loss:     0.0043 Validation Accuracy: 0.468600
# Epoch 52, CIFAR-10 Batch 2:  Loss:     0.0014 Validation Accuracy: 0.458600
# Epoch 52, CIFAR-10 Batch 3:  Loss:     0.0013 Validation Accuracy: 0.472000
# Epoch 52, CIFAR-10 Batch 4:  Loss:     0.0007 Validation Accuracy: 0.476000
# Epoch 52, CIFAR-10 Batch 5:  Loss:     0.0031 Validation Accuracy: 0.479600
# Epoch 53, CIFAR-10 Batch 1:  Loss:     0.0032 Validation Accuracy: 0.474800
# Epoch 53, CIFAR-10 Batch 2:  Loss:     0.0006 Validation Accuracy: 0.459800
# Epoch 53, CIFAR-10 Batch 3:  Loss:     0.0010 Validation Accuracy: 0.467800
# Epoch 53, CIFAR-10 Batch 4:  Loss:     0.0008 Validation Accuracy: 0.476400
# Epoch 53, CIFAR-10 Batch 5:  Loss:     0.0027 Validation Accuracy: 0.476200
# Epoch 54, CIFAR-10 Batch 1:  Loss:     0.0014 Validation Accuracy: 0.480800
# Epoch 54, CIFAR-10 Batch 2:  Loss:     0.0002 Validation Accuracy: 0.469400
# Epoch 54, CIFAR-10 Batch 3:  Loss:     0.0008 Validation Accuracy: 0.477200
# Epoch 54, CIFAR-10 Batch 4:  Loss:     0.0007 Validation Accuracy: 0.484400
# Epoch 54, CIFAR-10 Batch 5:  Loss:     0.0023 Validation Accuracy: 0.471600
# Epoch 55, CIFAR-10 Batch 1:  Loss:     0.0009 Validation Accuracy: 0.473200
# Epoch 55, CIFAR-10 Batch 2:  Loss:     0.0005 Validation Accuracy: 0.478200
# Epoch 55, CIFAR-10 Batch 3:  Loss:     0.0004 Validation Accuracy: 0.473400
# Epoch 55, CIFAR-10 Batch 4:  Loss:     0.0008 Validation Accuracy: 0.495200
# Epoch 55, CIFAR-10 Batch 5:  Loss:     0.0011 Validation Accuracy: 0.470600
# Epoch 56, CIFAR-10 Batch 1:  Loss:     0.0001 Validation Accuracy: 0.476600
# Epoch 56, CIFAR-10 Batch 2:  Loss:     0.0002 Validation Accuracy: 0.484600
# Epoch 56, CIFAR-10 Batch 3:  Loss:     0.0008 Validation Accuracy: 0.470600
# Epoch 56, CIFAR-10 Batch 4:  Loss:     0.0014 Validation Accuracy: 0.490200
# Epoch 56, CIFAR-10 Batch 5:  Loss:     0.0016 Validation Accuracy: 0.480800
# Epoch 57, CIFAR-10 Batch 1:  Loss:     0.0003 Validation Accuracy: 0.487200
# Epoch 57, CIFAR-10 Batch 2:  Loss:     0.0001 Validation Accuracy: 0.476400
# Epoch 57, CIFAR-10 Batch 3:  Loss:     0.0011 Validation Accuracy: 0.487800
# Epoch 57, CIFAR-10 Batch 4:  Loss:     0.0002 Validation Accuracy: 0.494400
# Epoch 57, CIFAR-10 Batch 5:  Loss:     0.0008 Validation Accuracy: 0.473000
# Epoch 58, CIFAR-10 Batch 1:  Loss:     0.0009 Validation Accuracy: 0.478200
# Epoch 58, CIFAR-10 Batch 2:  Loss:     0.0001 Validation Accuracy: 0.479400
# Epoch 58, CIFAR-10 Batch 3:  Loss:     0.0006 Validation Accuracy: 0.473200
# Epoch 58, CIFAR-10 Batch 4:  Loss:     0.0004 Validation Accuracy: 0.485000
# Epoch 58, CIFAR-10 Batch 5:  Loss:     0.0010 Validation Accuracy: 0.483200
# Epoch 59, CIFAR-10 Batch 1:  Loss:     0.0003 Validation Accuracy: 0.480800
# Epoch 59, CIFAR-10 Batch 2:  Loss:     0.0003 Validation Accuracy: 0.486600
# Epoch 59, CIFAR-10 Batch 3:  Loss:     0.0004 Validation Accuracy: 0.480000
# Epoch 59, CIFAR-10 Batch 4:  Loss:     0.0006 Validation Accuracy: 0.480600
# Epoch 59, CIFAR-10 Batch 5:  Loss:     0.0010 Validation Accuracy: 0.466800
# Epoch 60, CIFAR-10 Batch 1:  Loss:     0.0004 Validation Accuracy: 0.469800
# Epoch 60, CIFAR-10 Batch 2:  Loss:     0.0003 Validation Accuracy: 0.472000
# Epoch 60, CIFAR-10 Batch 3:  Loss:     0.0002 Validation Accuracy: 0.472800
# Epoch 60, CIFAR-10 Batch 4:  Loss:     0.0003 Validation Accuracy: 0.478600
# Epoch 60, CIFAR-10 Batch 5:  Loss:     0.0008 Validation Accuracy: 0.466800
# Epoch 61, CIFAR-10 Batch 1:  Loss:     0.0008 Validation Accuracy: 0.466800
# Epoch 61, CIFAR-10 Batch 2:  Loss:     0.0006 Validation Accuracy: 0.472200
# Epoch 61, CIFAR-10 Batch 3:  Loss:     0.0002 Validation Accuracy: 0.478800
# Epoch 61, CIFAR-10 Batch 4:  Loss:     0.0008 Validation Accuracy: 0.480000
# Epoch 61, CIFAR-10 Batch 5:  Loss:     0.0010 Validation Accuracy: 0.477200
# Epoch 62, CIFAR-10 Batch 1:  Loss:     0.0001 Validation Accuracy: 0.459600
# Epoch 62, CIFAR-10 Batch 2:  Loss:     0.0010 Validation Accuracy: 0.487600
# Epoch 62, CIFAR-10 Batch 3:  Loss:     0.0007 Validation Accuracy: 0.475800
# Epoch 62, CIFAR-10 Batch 4:  Loss:     0.0003 Validation Accuracy: 0.472400
# Epoch 62, CIFAR-10 Batch 5:  Loss:     0.0023 Validation Accuracy: 0.461200
# Epoch 63, CIFAR-10 Batch 1:  Loss:     0.0011 Validation Accuracy: 0.462600
# Epoch 63, CIFAR-10 Batch 2:  Loss:     0.0002 Validation Accuracy: 0.494800
# Epoch 63, CIFAR-10 Batch 3:  Loss:     0.0002 Validation Accuracy: 0.488200
# Epoch 63, CIFAR-10 Batch 4:  Loss:     0.0015 Validation Accuracy: 0.479800
# Epoch 63, CIFAR-10 Batch 5:  Loss:     0.0005 Validation Accuracy: 0.479000
# Epoch 64, CIFAR-10 Batch 1:  Loss:     0.0007 Validation Accuracy: 0.464600
# Epoch 64, CIFAR-10 Batch 2:  Loss:     0.0001 Validation Accuracy: 0.485800
# Epoch 64, CIFAR-10 Batch 3:  Loss:     0.0003 Validation Accuracy: 0.481000
# Epoch 64, CIFAR-10 Batch 4:  Loss:     0.0006 Validation Accuracy: 0.468600
# Epoch 64, CIFAR-10 Batch 5:  Loss:     0.0005 Validation Accuracy: 0.475000
# Epoch 65, CIFAR-10 Batch 1:  Loss:     0.0001 Validation Accuracy: 0.464800
# Epoch 65, CIFAR-10 Batch 2:  Loss:     0.0001 Validation Accuracy: 0.487000
# Epoch 65, CIFAR-10 Batch 3:  Loss:     0.0008 Validation Accuracy: 0.474000
# Epoch 65, CIFAR-10 Batch 4:  Loss:     0.0008 Validation Accuracy: 0.480400
# Epoch 65, CIFAR-10 Batch 5:  Loss:     0.0002 Validation Accuracy: 0.477400
# Epoch 66, CIFAR-10 Batch 1:  Loss:     0.0006 Validation Accuracy: 0.465000
# Epoch 66, CIFAR-10 Batch 2:  Loss:     0.0004 Validation Accuracy: 0.490800
# Epoch 66, CIFAR-10 Batch 3:  Loss:     0.0009 Validation Accuracy: 0.476600
# Epoch 66, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy: 0.483600
# Epoch 66, CIFAR-10 Batch 5:  Loss:     0.0005 Validation Accuracy: 0.481400
# Epoch 67, CIFAR-10 Batch 1:  Loss:     0.0004 Validation Accuracy: 0.462400
# Epoch 67, CIFAR-10 Batch 2:  Loss:     0.0003 Validation Accuracy: 0.485400
# Epoch 67, CIFAR-10 Batch 3:  Loss:     0.0008 Validation Accuracy: 0.478600
# Epoch 67, CIFAR-10 Batch 4:  Loss:     0.0003 Validation Accuracy: 0.482000
# Epoch 67, CIFAR-10 Batch 5:  Loss:     0.0004 Validation Accuracy: 0.477600
# Epoch 68, CIFAR-10 Batch 1:  Loss:     0.0003 Validation Accuracy: 0.475200
# Epoch 68, CIFAR-10 Batch 2:  Loss:     0.0001 Validation Accuracy: 0.481000
# Epoch 68, CIFAR-10 Batch 3:  Loss:     0.0003 Validation Accuracy: 0.469600
# Epoch 68, CIFAR-10 Batch 4:  Loss:     0.0012 Validation Accuracy: 0.477200
# Epoch 68, CIFAR-10 Batch 5:  Loss:     0.0002 Validation Accuracy: 0.474800
# Epoch 69, CIFAR-10 Batch 1:  Loss:     0.0002 Validation Accuracy: 0.475800
# Epoch 69, CIFAR-10 Batch 2:  Loss:     0.0003 Validation Accuracy: 0.487600
# Epoch 69, CIFAR-10 Batch 3:  Loss:     0.0001 Validation Accuracy: 0.475000
# Epoch 69, CIFAR-10 Batch 4:  Loss:     0.0008 Validation Accuracy: 0.474800
# Epoch 69, CIFAR-10 Batch 5:  Loss:     0.0003 Validation Accuracy: 0.488400
# Epoch 70, CIFAR-10 Batch 1:  Loss:     0.0002 Validation Accuracy: 0.460000
# Epoch 70, CIFAR-10 Batch 2:  Loss:     0.0004 Validation Accuracy: 0.484800
# Epoch 70, CIFAR-10 Batch 3:  Loss:     0.0002 Validation Accuracy: 0.467000
# Epoch 70, CIFAR-10 Batch 4:  Loss:     0.0001 Validation Accuracy: 0.474000
# Epoch 70, CIFAR-10 Batch 5:  Loss:     0.0004 Validation Accuracy: 0.480400
# Epoch 71, CIFAR-10 Batch 1:  Loss:     0.0006 Validation Accuracy: 0.471200
# Epoch 71, CIFAR-10 Batch 2:  Loss:     0.0004 Validation Accuracy: 0.489400
# Epoch 71, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy: 0.474400
# Epoch 71, CIFAR-10 Batch 4:  Loss:     0.0010 Validation Accuracy: 0.485600
# Epoch 71, CIFAR-10 Batch 5:  Loss:     0.0007 Validation Accuracy: 0.477400
# Epoch 72, CIFAR-10 Batch 1:  Loss:     0.0003 Validation Accuracy: 0.465400
# Epoch 72, CIFAR-10 Batch 2:  Loss:     0.0001 Validation Accuracy: 0.480000
# Epoch 72, CIFAR-10 Batch 3:  Loss:     0.0001 Validation Accuracy: 0.475600
# Epoch 72, CIFAR-10 Batch 4:  Loss:     0.0001 Validation Accuracy: 0.474800
# Epoch 72, CIFAR-10 Batch 5:  Loss:     0.0013 Validation Accuracy: 0.459600
# Epoch 73, CIFAR-10 Batch 1:  Loss:     0.0003 Validation Accuracy: 0.471800
# Epoch 73, CIFAR-10 Batch 2:  Loss:     0.0006 Validation Accuracy: 0.469800
# Epoch 73, CIFAR-10 Batch 3:  Loss:     0.0002 Validation Accuracy: 0.468600
# Epoch 73, CIFAR-10 Batch 4:  Loss:     0.0002 Validation Accuracy: 0.479200
# Epoch 73, CIFAR-10 Batch 5:  Loss:     0.0002 Validation Accuracy: 0.488000
# Epoch 74, CIFAR-10 Batch 1:  Loss:     0.0002 Validation Accuracy: 0.478800
# Epoch 74, CIFAR-10 Batch 2:  Loss:     0.0002 Validation Accuracy: 0.476800
# Epoch 74, CIFAR-10 Batch 3:  Loss:     0.0001 Validation Accuracy: 0.473400
# Epoch 74, CIFAR-10 Batch 4:  Loss:     0.0002 Validation Accuracy: 0.477400
# Epoch 74, CIFAR-10 Batch 5:  Loss:     0.0012 Validation Accuracy: 0.475600
# Epoch 75, CIFAR-10 Batch 1:  Loss:     0.0005 Validation Accuracy: 0.460400
# Epoch 75, CIFAR-10 Batch 2:  Loss:     0.0006 Validation Accuracy: 0.482400
# Epoch 75, CIFAR-10 Batch 3:  Loss:     0.0001 Validation Accuracy: 0.479800
# Epoch 75, CIFAR-10 Batch 4:  Loss:     0.0003 Validation Accuracy: 0.479400
# Epoch 75, CIFAR-10 Batch 5:  Loss:     0.0007 Validation Accuracy: 0.483200
# Epoch 76, CIFAR-10 Batch 1:  Loss:     0.0013 Validation Accuracy: 0.466400
# Epoch 76, CIFAR-10 Batch 2:  Loss:     0.0002 Validation Accuracy: 0.472000
# Epoch 76, CIFAR-10 Batch 3:  Loss:     0.0004 Validation Accuracy: 0.469200
# Epoch 76, CIFAR-10 Batch 4:  Loss:     0.0002 Validation Accuracy: 0.463000
# Epoch 76, CIFAR-10 Batch 5:  Loss:     0.0013 Validation Accuracy: 0.474200
# Epoch 77, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.461000
# Epoch 77, CIFAR-10 Batch 2:  Loss:     0.0006 Validation Accuracy: 0.477200
# Epoch 77, CIFAR-10 Batch 3:  Loss:     0.0005 Validation Accuracy: 0.467200
# Epoch 77, CIFAR-10 Batch 4:  Loss:     0.0001 Validation Accuracy: 0.465400
# Epoch 77, CIFAR-10 Batch 5:  Loss:     0.0005 Validation Accuracy: 0.468800
# Epoch 78, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.463800
# Epoch 78, CIFAR-10 Batch 2:  Loss:     0.0001 Validation Accuracy: 0.465400
# Epoch 78, CIFAR-10 Batch 3:  Loss:     0.0001 Validation Accuracy: 0.476200
# Epoch 78, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy: 0.469400
# Epoch 78, CIFAR-10 Batch 5:  Loss:     0.0003 Validation Accuracy: 0.476000
# Epoch 79, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.459800
# Epoch 79, CIFAR-10 Batch 2:  Loss:     0.0001 Validation Accuracy: 0.472800
# Epoch 79, CIFAR-10 Batch 3:  Loss:     0.0003 Validation Accuracy: 0.469000
# Epoch 79, CIFAR-10 Batch 4:  Loss:     0.0011 Validation Accuracy: 0.471000
# Epoch 79, CIFAR-10 Batch 5:  Loss:     0.0009 Validation Accuracy: 0.474400
# Epoch 80, CIFAR-10 Batch 1:  Loss:     0.0001 Validation Accuracy: 0.469600
# Epoch 80, CIFAR-10 Batch 2:  Loss:     0.0001 Validation Accuracy: 0.479800
# Epoch 80, CIFAR-10 Batch 3:  Loss:     0.0006 Validation Accuracy: 0.472600
# Epoch 80, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy: 0.472800
# Epoch 80, CIFAR-10 Batch 5:  Loss:     0.0001 Validation Accuracy: 0.471400
# Epoch 81, CIFAR-10 Batch 1:  Loss:     0.0001 Validation Accuracy: 0.471400
# Epoch 81, CIFAR-10 Batch 2:  Loss:     0.0002 Validation Accuracy: 0.482800
# Epoch 81, CIFAR-10 Batch 3:  Loss:     0.0007 Validation Accuracy: 0.484000
# Epoch 81, CIFAR-10 Batch 4:  Loss:     0.0006 Validation Accuracy: 0.481200
# Epoch 81, CIFAR-10 Batch 5:  Loss:     0.0006 Validation Accuracy: 0.474800
# Epoch 82, CIFAR-10 Batch 1:  Loss:     0.0001 Validation Accuracy: 0.475600
# Epoch 82, CIFAR-10 Batch 2:  Loss:     0.0009 Validation Accuracy: 0.486000
# Epoch 82, CIFAR-10 Batch 3:  Loss:     0.0005 Validation Accuracy: 0.466200
# Epoch 82, CIFAR-10 Batch 4:  Loss:     0.0012 Validation Accuracy: 0.478600
# Epoch 82, CIFAR-10 Batch 5:  Loss:     0.0005 Validation Accuracy: 0.475800
# Epoch 83, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.476600
# Epoch 83, CIFAR-10 Batch 2:  Loss:     0.0002 Validation Accuracy: 0.484600
# Epoch 83, CIFAR-10 Batch 3:  Loss:     0.0007 Validation Accuracy: 0.471400
# Epoch 83, CIFAR-10 Batch 4:  Loss:     0.0002 Validation Accuracy: 0.469400
# Epoch 83, CIFAR-10 Batch 5:  Loss:     0.0001 Validation Accuracy: 0.479000
# Epoch 84, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.481800
# Epoch 84, CIFAR-10 Batch 2:  Loss:     0.0001 Validation Accuracy: 0.488400
# Epoch 84, CIFAR-10 Batch 3:  Loss:     0.0004 Validation Accuracy: 0.475600
# Epoch 84, CIFAR-10 Batch 4:  Loss:     0.0001 Validation Accuracy: 0.474600
# Epoch 84, CIFAR-10 Batch 5:  Loss:     0.0011 Validation Accuracy: 0.484400
# Epoch 85, CIFAR-10 Batch 1:  Loss:     0.0001 Validation Accuracy: 0.470800
# Epoch 85, CIFAR-10 Batch 2:  Loss:     0.0003 Validation Accuracy: 0.486800
# Epoch 85, CIFAR-10 Batch 3:  Loss:     0.0001 Validation Accuracy: 0.471200
# Epoch 85, CIFAR-10 Batch 4:  Loss:     0.0004 Validation Accuracy: 0.473400
# Epoch 85, CIFAR-10 Batch 5:  Loss:     0.0006 Validation Accuracy: 0.470400
# Epoch 86, CIFAR-10 Batch 1:  Loss:     0.0002 Validation Accuracy: 0.471200
# Epoch 86, CIFAR-10 Batch 2:  Loss:     0.0001 Validation Accuracy: 0.480400
# Epoch 86, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy: 0.474600
# Epoch 86, CIFAR-10 Batch 4:  Loss:     0.0003 Validation Accuracy: 0.476800
# Epoch 86, CIFAR-10 Batch 5:  Loss:     0.0005 Validation Accuracy: 0.472000
# Epoch 87, CIFAR-10 Batch 1:  Loss:     0.0002 Validation Accuracy: 0.482200
# Epoch 87, CIFAR-10 Batch 2:  Loss:     0.0001 Validation Accuracy: 0.488200
# Epoch 87, CIFAR-10 Batch 3:  Loss:     0.0002 Validation Accuracy: 0.483800
# Epoch 87, CIFAR-10 Batch 4:  Loss:     0.0002 Validation Accuracy: 0.468600
# Epoch 87, CIFAR-10 Batch 5:  Loss:     0.0001 Validation Accuracy: 0.468800
# Epoch 88, CIFAR-10 Batch 1:  Loss:     0.0002 Validation Accuracy: 0.461200
# Epoch 88, CIFAR-10 Batch 2:  Loss:     0.0002 Validation Accuracy: 0.486600
# Epoch 88, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy: 0.480000
# Epoch 88, CIFAR-10 Batch 4:  Loss:     0.0006 Validation Accuracy: 0.472400
# Epoch 88, CIFAR-10 Batch 5:  Loss:     0.0003 Validation Accuracy: 0.468000
# Epoch 89, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.483000
# Epoch 89, CIFAR-10 Batch 2:  Loss:     0.0003 Validation Accuracy: 0.481000
# Epoch 89, CIFAR-10 Batch 3:  Loss:     0.0001 Validation Accuracy: 0.487800
# Epoch 89, CIFAR-10 Batch 4:  Loss:     0.0003 Validation Accuracy: 0.478200
# Epoch 89, CIFAR-10 Batch 5:  Loss:     0.0005 Validation Accuracy: 0.469600
# Epoch 90, CIFAR-10 Batch 1:  Loss:     0.0002 Validation Accuracy: 0.464800
# Epoch 90, CIFAR-10 Batch 2:  Loss:     0.0002 Validation Accuracy: 0.478600
# Epoch 90, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy: 0.484400
# Epoch 90, CIFAR-10 Batch 4:  Loss:     0.0005 Validation Accuracy: 0.478200
# Epoch 90, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy: 0.473800
# Epoch 91, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.480400
# Epoch 91, CIFAR-10 Batch 2:  Loss:     0.0001 Validation Accuracy: 0.479000
# Epoch 91, CIFAR-10 Batch 3:  Loss:     0.0003 Validation Accuracy: 0.472600
# Epoch 91, CIFAR-10 Batch 4:  Loss:     0.0001 Validation Accuracy: 0.484800
# Epoch 91, CIFAR-10 Batch 5:  Loss:     0.0002 Validation Accuracy: 0.476600
# Epoch 92, CIFAR-10 Batch 1:  Loss:     0.0001 Validation Accuracy: 0.469200
# Epoch 92, CIFAR-10 Batch 2:  Loss:     0.0003 Validation Accuracy: 0.483000
# Epoch 92, CIFAR-10 Batch 3:  Loss:     0.0001 Validation Accuracy: 0.483800
# Epoch 92, CIFAR-10 Batch 4:  Loss:     0.0004 Validation Accuracy: 0.479200
# Epoch 92, CIFAR-10 Batch 5:  Loss:     0.0007 Validation Accuracy: 0.467600
# Epoch 93, CIFAR-10 Batch 1:  Loss:     0.0001 Validation Accuracy: 0.470000
# Epoch 93, CIFAR-10 Batch 2:  Loss:     0.0009 Validation Accuracy: 0.485800
# Epoch 93, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy: 0.487800
# Epoch 93, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy: 0.487600
# Epoch 93, CIFAR-10 Batch 5:  Loss:     0.0004 Validation Accuracy: 0.482600
# Epoch 94, CIFAR-10 Batch 1:  Loss:     0.0002 Validation Accuracy: 0.485800
# Epoch 94, CIFAR-10 Batch 2:  Loss:     0.0002 Validation Accuracy: 0.479000
# Epoch 94, CIFAR-10 Batch 3:  Loss:     0.0002 Validation Accuracy: 0.482200
# Epoch 94, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy: 0.475200
# Epoch 94, CIFAR-10 Batch 5:  Loss:     0.0002 Validation Accuracy: 0.465800
# Epoch 95, CIFAR-10 Batch 1:  Loss:     0.0001 Validation Accuracy: 0.461400
# Epoch 95, CIFAR-10 Batch 2:  Loss:     0.0001 Validation Accuracy: 0.474600
# Epoch 95, CIFAR-10 Batch 3:  Loss:     0.0002 Validation Accuracy: 0.483200
# Epoch 95, CIFAR-10 Batch 4:  Loss:     0.0002 Validation Accuracy: 0.473800
# Epoch 95, CIFAR-10 Batch 5:  Loss:     0.0006 Validation Accuracy: 0.482400
# Epoch 96, CIFAR-10 Batch 1:  Loss:     0.0011 Validation Accuracy: 0.459000
# Epoch 96, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy: 0.480000
# Epoch 96, CIFAR-10 Batch 3:  Loss:     0.0002 Validation Accuracy: 0.481400
# Epoch 96, CIFAR-10 Batch 4:  Loss:     0.0001 Validation Accuracy: 0.477600
# Epoch 96, CIFAR-10 Batch 5:  Loss:     0.0006 Validation Accuracy: 0.480000
# Epoch 97, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.480400
# Epoch 97, CIFAR-10 Batch 2:  Loss:     0.0001 Validation Accuracy: 0.468200
# Epoch 97, CIFAR-10 Batch 3:  Loss:     0.0001 Validation Accuracy: 0.489400
# Epoch 97, CIFAR-10 Batch 4:  Loss:     0.0001 Validation Accuracy: 0.467800
# Epoch 97, CIFAR-10 Batch 5:  Loss:     0.0012 Validation Accuracy: 0.475800
# Epoch 98, CIFAR-10 Batch 1:  Loss:     0.0001 Validation Accuracy: 0.466400
# Epoch 98, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy: 0.477200
# Epoch 98, CIFAR-10 Batch 3:  Loss:     0.0001 Validation Accuracy: 0.486600
# Epoch 98, CIFAR-10 Batch 4:  Loss:     0.0004 Validation Accuracy: 0.480200
# Epoch 98, CIFAR-10 Batch 5:  Loss:     0.0003 Validation Accuracy: 0.474400
# Epoch 99, CIFAR-10 Batch 1:  Loss:     0.0002 Validation Accuracy: 0.459200
# Epoch 99, CIFAR-10 Batch 2:  Loss:     0.0001 Validation Accuracy: 0.477000
# Epoch 99, CIFAR-10 Batch 3:  Loss:     0.0001 Validation Accuracy: 0.479600
# Epoch 99, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy: 0.474800
# Epoch 99, CIFAR-10 Batch 5:  Loss:     0.0002 Validation Accuracy: 0.472200
# Epoch 100, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.465000
# Epoch 100, CIFAR-10 Batch 2:  Loss:     0.0001 Validation Accuracy: 0.476400
# Epoch 100, CIFAR-10 Batch 3:  Loss:     0.0002 Validation Accuracy: 0.491600
# Epoch 100, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy: 0.486400
# Epoch 100, CIFAR-10 Batch 5:  Loss:     0.0003 Validation Accuracy: 0.462400

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_test.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for test_feature_batch, test_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.46318359375

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
